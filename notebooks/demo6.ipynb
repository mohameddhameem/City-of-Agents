# %% [markdown]
# # load code text

# %%
# Install required dependencies (safe to run multiple times)
# %pip install -q torch torch_geometric datasets transformers sentence-transformers scikit-learn seaborn

from datasets import load_dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the CoDET-M4 dataset
dataset = load_dataset("DaniilOr/CoDET-M4")

# Set visualization style
plt.style.use('seaborn-v0_8-darkgrid')

# Keep only Python examples
python_dataset = dataset['train'].filter(lambda x: x['language'] == 'python')
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import random

# Get unique models from the dataset (filtering out NoneType first)
# Some rows might have None for 'model', we want to ignore them or handle them.
all_models = [m for m in python_dataset['model'] if m is not None]
unique_models = sorted(list(set(all_models)))
print(f"Found {len(unique_models)} unique models: {unique_models}")

selected_indices = []

# Select 5 samples for each model
for model in unique_models:
    # We must ensure we match indices in the original python_dataset
    # enumerate(python_dataset['model']) gives global indices within python_dataset
    model_indices = [
        i for i, m in enumerate(python_dataset['model']) 
        if m == model
    ]
    
    # Sample 5, or all if less than 5
    count = min(5, len(model_indices))
    features = random.sample(model_indices, count)
    selected_indices.extend(features)

# Shuffle the combined indices
random.shuffle(selected_indices)

sample_code = python_dataset.select(selected_indices)

print(f"Total samples selected: {len(sample_code)}")
sample_code
# Out:
# Found 6 unique models: ['codellama', 'gpt', 'human', 'llama3.1', 'nxcode', 'qwen1.5']
# Total samples selected: 30
# Dataset({
#     features: ['code', 'language', 'model', 'split', 'target', 'source', 'features', 'cleaned_code', '__index_level_0__'],
#     num_rows: 30
# })

# %%
# text to ast

# %%
import ast

# Initialize lists
valid_indices = []
sample_asts = []

print(f"Original sample size: {len(sample_code)}")
print("Converting sample_code to AST and filtering...")

for idx, example in enumerate(sample_code):
    try:
        # Parse the code content
        tree = ast.parse(example['code'])
        # If successful, keep track
        sample_asts.append(tree)
        valid_indices.append(idx)
    except SyntaxError as e:
        print(f"Skipping example {idx} due to SyntaxError: {e}")
    except Exception as e:
        print(f"Skipping example {idx} due to Error: {e}")

# Filter the dataset to keep only valid examples
if len(valid_indices) < len(sample_code):
    print(f"Filtering out {len(sample_code) - len(valid_indices)} invalid examples.")
    # Assuming sample_code is a HF Dataset, .select() creates a subset
    sample_code = sample_code.select(valid_indices)
else:
    print("All examples are valid.")

print(f"Conversion complete. Retained {len(sample_code)} valid examples and AST objects.")

# Show structure of the first AST as a verification
if sample_asts:
    print(f"\nExample AST structure (Item 0):")
    print(ast.dump(sample_asts[0], indent=2))
# Out:
# Original sample size: 30
# Converting sample_code to AST and filtering...
# Skipping example 1 due to SyntaxError: expected an indented block after function definition on line 1 (<unknown>, line 1)
# Skipping example 6 due to SyntaxError: '(' was never closed (<unknown>, line 23)
# Skipping example 27 due to SyntaxError: invalid syntax (<unknown>, line 2)
# Skipping example 28 due to SyntaxError: expected an indented block after function definition on line 1 (<unknown>, line 1)
# Filtering out 4 invalid examples.
# Conversion complete. Retained 26 valid examples and AST objects.
#
# Example AST structure (Item 0):
# Module(
#   body=[
#     FunctionDef(
#       name='incrby',
#       args=arguments(
#         args=[
#           arg(arg='self'),
#           arg(arg='key'),
#           arg(arg='increment')]),
#       body=[
#         Expr(
#           value=Constant(value='\n    Increment the integer value of a key by the given amount.\n\n    :raises TypeError: if increment is not int\n    ')),
#         If(
#           test=UnaryOp(
#             op=Not(),
#             operand=Call(
#               func=Name(id='isinstance', ctx=Load()),
#               args=[
#                 Name(id='increment', ctx=Load()),
#                 Name(id='int', ctx=Load())])),
#           body=[
#             Raise(
#               exc=Call(
#                 func=Name(id='TypeError', ctx=Load()),
#                 args=[
#                   Constant(value='increment must be an integer')]))]),
#         AugAssign(
#           target=Subscript(
#             value=Name(id='self', ctx=Load()),
#             slice=Name(id='key', ctx=Load()),
#             ctx=Store()),
#           op=Add(),
#           value=Name(id='increment', ctx=Load()))])])

# %% [markdown]
# # ast to pyg

# %%
import torch
from torch_geometric.data import Data
import ast

def ast_to_pyg_data(code_str, target_label):
    """
    Convert python code string to PyG Data object via AST.
    """
    try:
        tree = ast.parse(code_str)
    except SyntaxError:
        return None

    node_list = []
    edge_index = [[], []] # [source_nodes, target_nodes]
    edge_attr = [] # Edge text (field name)
    
    # Map node object id to index
    node_to_idx = {}

    def visit(node, parent_idx=None, relation=None):
        nonlocal node_list, edge_index, edge_attr
        
        # Current node index
        curr_idx = len(node_list)
        node_to_idx[id(node)] = curr_idx
        
        # Node features
        node_type = type(node).__name__
        
        node_list.append({
            'type': node_type
        })
        
        # Add edge if parent exists
        if parent_idx is not None:
            edge_index[0].append(parent_idx)
            edge_index[1].append(curr_idx)
            edge_attr.append(relation if relation else "child")
            
        # Traverse children
        for field, value in ast.iter_fields(node):
            if isinstance(value, list):
                for item in value:
                    if isinstance(item, ast.AST):
                        visit(item, curr_idx, field)
            elif isinstance(value, ast.AST):
                visit(value, curr_idx, field)

    visit(tree)

    if not node_list:
        return None
        
    # Convert to PyG Data
    
    data = Data(
        edge_index=torch.tensor(edge_index, dtype=torch.long),
        num_nodes=len(node_list),
        node_texts=[n['type'] for n in node_list],
        edge_texts=edge_attr,
        code=code_str,
        y=target_label
    )
    
    return data

# Convert the sample_code dataset
pyg_dataset = []

print("Converting to PyG Data objects...")
for idx, item in enumerate(sample_code):
    data = ast_to_pyg_data(item['code'], item['model'])
    if data:
        pyg_dataset.append(data)
    else:
        print(f"Skipping item {idx} due to parse error or empty graph.")

print(f"Conversion complete. Created {len(pyg_dataset)} PyG Data objects.")
# Out:
# Converting to PyG Data objects...
# Conversion complete. Created 26 PyG Data objects.

# %% [markdown]
# # adding features by text encoder

# %%
import os
import sys

# Ensure project root is on the Python path so we can import create_feature
root_dir = os.path.abspath("..")
if root_dir not in sys.path:
    sys.path.append(root_dir)

from create_feature import encode_text_graph

# Apply the encoding
# Using 'tiny' model (MiniLM) for efficiency in this demo
try:
    pyg_dataset = encode_text_graph(pyg_dataset, lm_type="tiny")
    
    # Verify the first graph
    if len(pyg_dataset) > 0:
        g = pyg_dataset[0]
        print("\nFeature Generation Complete.")
        print(f"Node Embeddings (x): {g.x.shape if hasattr(g, 'x') and g.x is not None else 'None'}")
        print(f"Edge Embeddings (edge_attr): {g.edge_attr.shape if hasattr(g, 'edge_attr') and g.edge_attr is not None else 'None'}")
except NameError:
    print("Error: pyg_dataset is not defined. Please run the previous cells first.")
except Exception as e:
    print(f"An error occurred during encoding: {e}")
# Out:
# Using device: cpu
# Loading model: sentence-transformers/all-MiniLM-L6-v2
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Encoding features for 26 graphs...
# 100%|██████████| 26/26 [00:12<00:00,  2.14it/s]
# Feature Generation Complete.
# Node Embeddings (x): torch.Size([33, 384])
# Edge Embeddings (edge_attr): torch.Size([32, 384])

# %%
pyg_dataset
# Out:
# [Data(edge_index=[2, 32], y='llama3.1', num_nodes=33, node_texts=[33], edge_texts=[32], code='def incrby(self, key, increment):
#      """
#      Increment the integer value of a key by the given amount.
#
#      :raises TypeError: if increment is not int
#      """
#      if not isinstance(increment, int):
#          raise TypeError("increment must be an integer")
#      self[key] += increment', x=[33, 384], edge_attr=[32, 384]),
#  Data(edge_index=[2, 64], y='qwen1.5', num_nodes=65, node_texts=[65], edge_texts=[64], code='def find_roll_numbers(students):
#      # Initialize an empty dictionary to store the class-wise roll numbers
#      class_rolls = {}
#
#      # Iterate over the list of students
#      for student in students:
#          # Extract the class and roll number from the student tuple
#          class_num,roll_num = student[0],student[1]
#
#          # Check if the class is already in the dictionary
#          if class_num in class_rolls:
#              # If it is, append the roll number to the list of roll numbers for that class
#              class_rolls[class_num].append(roll_num)
#          else:
#              # If it isn't, create a new entry in the dictionary with the class as the key and a list containing the roll number as the value
#              class_rolls[class_num] = [roll_num]
#
#      # Return the dictionary containing the class-wise roll numbers
#      return class_rolls', x=[65, 384], edge_attr=[64, 384]),
#  Data(edge_index=[2, 97], y='nxcode', num_nodes=98, node_texts=[98], edge_texts=[97], code='def freqAlphabets(s):
#      res = ""
#      i = len(s) - 1
#      while i >= 0:
#          if s[i] == "#":
#              res += chr(96 + int(s[i - 2:i]))
#              i -= 3
#          else:
#              res += chr(96 + int(s[i]))
#              i -= 1
#      return res[::-1]', x=[98, 384], edge_attr=[97, 384]),
#  Data(edge_index=[2, 67], y='gpt', num_nodes=68, node_texts=[68], edge_texts=[67], code='def check_motor_eprom_configuration(config, dxl_io, motor_names):
#      """
#      Change the angles limits depending on the robot configuration;
#      Check if the return delay time is set to 0.
#      """
#      for motor in motor_names:
#          if motor in config:
#              angle_limits = config[motor].get('angle_limits', None)
#              if angle_limits:
#                  dxl_io.set_angle_limits(motor, angle_limits)
#
#      return_delay_time = dxl_io.get_return_delay_time()
#      if return_delay_time != 0:
#          dxl_io.set_return_delay_time(0)', x=[68, 384], edge_attr=[67, 384]),
#  Data(edge_index=[2, 29], y='llama3.1', num_nodes=30, node_texts=[30], edge_texts=[29], code='def clear_rightmost_set_bit(n):
#      return n & (n - 1)
#
#  print(clear_rightmost_set_bit(10))  # Output: 8
#  print(clear_rightmost_set_bit(18))  # Output: 14', x=[30, 384], edge_attr=[29, 384]),
#  Data(edge_index=[2, 448], y='human', num_nodes=449, node_texts=[449], edge_texts=[448], code='#import io, os
#
#  #input = io.BytesIO(os.read(0, os.fstat(0).st_size)).readline
#
#
#
#  def mergeSort(arr,letter):
#
#      if len(arr) > 1:
#
#
#
#           # Finding the mid of the array
#
#          mid = len(arr)//2
#
#
#
#          # Dividing the array elements
#
#          L = arr[:mid]
#
#
#
#          # into 2 halves
#
#          R = arr[mid:]
#
#
#
#          # Sorting the first half
#
#          mergeSort(L,letter)
#
#
#
#          # Sorting the second half
#
#          mergeSort(R,letter)
#
#
#
#          i = j = k = 0
#
#
#
#          # Copy data to temp arrays L[] and R[]
#
#          while i < len(L) and j < len(R):
#
#              if 2*L[i].count(letter)-len(L[i]) > 2*R[j].count(letter)-len(R[j]):
#
#                  arr[k] = L[i]
#
#                  i += 1
#
#              else:
#
#                  arr[k] = R[j]
#
#                  j += 1
#
#              k += 1
#
#
#
#          # Checking if any element was left
#
#          while i < len(L):
#
#              arr[k] = L[i]
#
#              i += 1
#
#              k += 1
#
#
#
#          while j < len(R):
#
#              arr[k] = R[j]
#
#              j += 1
#
#              k += 1
#
#
#
#
#
#
#
#  t=int(input())
#
#  for case in range(t):
#
#    n=int(input())
#
#    arr=[]
#
#    mc=0
#
#    for _ in range(n):
#
#      arr.append(input())
#
#    alpha="abcde"
#
#    copyarr=arr.copy()
#
#    for i in alpha:
#
#      mergeSort(copyarr,i)
#
#      #print(copyarr)
#
#      letcount=copyarr[0].count(i)
#
#      othercount=len(copyarr[0])-letcount
#
#      copycopy=copyarr.copy()
#
#      copycopy.pop(0)
#
#      c=0
#
#      if letcount>othercount:
#
#        c+=1
#
#
#
#        for j in copycopy:
#
#          p=j.count(i)
#
#          letcount+=p
#
#          othercount+=len(j)-p
#
#          if letcount<=othercount:
#
#
#
#            break
#
#
#
#          c+=1
#
#
#
#      mc=max(mc,c)
#
#
#
#    print(mc)', x=[449, 384], edge_attr=[448, 384]),
#  Data(edge_index=[2, 43], y='qwen1.5', num_nodes=44, node_texts=[44], edge_texts=[43], code='n = int(input("Enter the number of rows: "))
#  for i in range(n, 0, -1):
#      for j in range(0, i):
#          print("* ", end="")
#      print("\r")', x=[44, 384], edge_attr=[43, 384]),
#  Data(edge_index=[2, 28], y='human', num_nodes=29, node_texts=[29], edge_texts=[28], code='def is_free(self):
#          """
#          Returns a concrete determination as to whether the chunk is free.
#          """
#          raise NotImplementedError("%s not implemented for %s" % (self.is_free.__func__.__name__,
#                                                                   self.__class__.__name__))', x=[29, 384], edge_attr=[28, 384]),
#  Data(edge_index=[2, 197], y='gpt', num_nodes=198, node_texts=[198], edge_texts=[197], code='def min_removals(test_cases):
#      results = []
#      for case in test_cases:
#          n, a = case
#          odd_count = sum(1 for x in a if x % 2 != 0)
#          even_count = n - odd_count
#
#          if odd_count % 2 == 0:
#              results.append(0)
#          else:
#              results.append(1)
#
#      return results
#
#  import sys
#  input = sys.stdin.read
#  data = input().splitlines()
#
#  t = int(data[0])
#  test_cases = []
#
#  index = 1
#  for _ in range(t):
#      n = int(data[index])
#      a = list(map(int, data[index + 1].split()))
#      test_cases.append((n, a))
#      index += 2
#
#  results = min_removals(test_cases)
#  for result in results:
#      print(result)', x=[198, 384], edge_attr=[197, 384]),
#  Data(edge_index=[2, 102], y='gpt', num_nodes=103, node_texts=[103], edge_texts=[102], code='def can_erase_string(s):
#      count_A = s.count('A')
#      count_B = s.count('B')
#      count_C = s.count('C')
#
#      # We can remove pairs (A, B) and (B, C)
#      # To completely erase the string, we need to satisfy the following conditions:
#      # 1. count_B must be equal to count_A + count_C because each B can pair with one A or one C
#      return count_B == count_A + count_C
#
#  t = int(input())
#  results = []
#  for _ in range(t):
#      s = input().strip()
#      if can_erase_string(s):
#          results.append("YES")
#      else:
#          results.append("NO")
#
#  print("\n".join(results))', x=[103, 384], edge_attr=[102, 384]),
#  Data(edge_index=[2, 56], y='gpt', num_nodes=57, node_texts=[57], edge_texts=[56], code='def dafopw(fname):
#      """
#      Open a DAF for subsequent write requests.
#
#      http://naif.jpl.nasa.gov/pub/naif/toolkit_docs/C/cspice/dafopw_c.html
#
#      :param fname: Name of DAF to be opened.
#      :type fname: str
#      :return: Handle assigned to DAF.
#      :rtype: int
#      """
#      import ctypes
#      from ctypes import c_int, c_char_p
#
#      # Load the CSPICE library
#      cspice = ctypes.CDLL('libcspice.so')  # Adjust the path as necessary
#
#      # Define the dafopw function's argument and return types
#      cspice.dafopw_c.argtypes = [c_char_p]
#      cspice.dafopw_c.restype = c_int
#
#      # Call the function and return the handle
#      handle = cspice.dafopw_c(fname.encode('utf-8'))
#      return handle', x=[57, 384], edge_attr=[56, 384]),
#  Data(edge_index=[2, 13], y='codellama', num_nodes=14, node_texts=[14], edge_texts=[13], code='def replace_space(string, char):
#      return string.replace(" ", char)', x=[14, 384], edge_attr=[13, 384]),
#  Data(edge_index=[2, 45], y='nxcode', num_nodes=46, node_texts=[46], edge_texts=[45], code='from bs4 import BeautifulSoup
#
#  # Create a BeautifulSoup object and feed it the HTML code
#  soup = BeautifulSoup('<html><body><p>Hello World</p></body></html>', 'html.parser')
#
#  # Get the paragraph element
#  p = soup.find('p')
#
#  # Create a new wrapper element
#  wrapper = soup.new_tag('div')
#
#  # Wrap the paragraph in the wrapper
#  p.wrap(wrapper)
#
#  # Print the updated HTML code
#  print(soup.prettify())', x=[46, 384], edge_attr=[45, 384]),
#  Data(edge_index=[2, 43], y='codellama', num_nodes=44, node_texts=[44], edge_texts=[43], code='def flatten(my_list):
#      result = []
#      for item in my_list:
#          if isinstance(item, list):
#              result.extend(flatten(item))
#          else:
#              result.append(item)
#      return result', x=[44, 384], edge_attr=[43, 384]),
#  Data(edge_index=[2, 27], y='llama3.1', num_nodes=28, node_texts=[28], edge_texts=[27], code='def parse_subscription(self, params={}, region='', subscription=None):
#      """
#      Parse a single subscription and reference it in its corresponding topic
#
#      :param params:                  Global parameters (defaults to {})
#      :param region:                  AWS Region
#      :param subscription:            SNS Subscription
#      """
#      # Add your parsing logic here
#      # For example, you might parse the subscription details and store them in a dictionary
#      parsed_subscription = {
#         'subscription': subscription,
#         'region': region,
#          'params': params
#      }
#
#      # You can also reference the parsed subscription in its corresponding topic
#      # For example, you might update the topic's attributes with the parsed subscription details
#      # topic.update(parsed_subscription)
#
#      return parsed_subscription', x=[28, 384], edge_attr=[27, 384]),
#  Data(edge_index=[2, 35], y='llama3.1', num_nodes=36, node_texts=[36], edge_texts=[35], code='import pandas as pd
#
#  df = pd.read_csv('titanic.csv')
#  print(df.columns)
#  print(df.shape)
#  print(df.dtypes)', x=[36, 384], edge_attr=[35, 384]),
#  Data(edge_index=[2, 97], y='codellama', num_nodes=98, node_texts=[98], edge_texts=[97], code='def count_chars(string):
#      chars = {}
#      for char in string:
#          if char in chars:
#              chars[char] += 1
#          else:
#              chars[char] = 1
#      return chars
#
#  def most_common(string):
#      char_counts = count_chars(string)
#      return max(char_counts.items(), key=lambda x: x[1])
#
#  def least_common(string):
#      char_counts = count_chars(string)
#      return min(char_counts.items(), key=lambda x: x[1])', x=[98, 384], edge_attr=[97, 384]),
#  Data(edge_index=[2, 18], y='llama3.1', num_nodes=19, node_texts=[19], edge_texts=[18], code='with open('file.txt', 'r') as file:
#      print(file.read())', x=[19, 384], edge_attr=[18, 384]),
#  Data(edge_index=[2, 144], y='qwen1.5', num_nodes=145, node_texts=[145], edge_texts=[144], code='def predict_party_victory(senate):
#      # Dictionary to keep track of banned senators
#      banned_senators = {}
#      # Counter to keep track of number of R and D senators
#      R, D = 0, 0
#      # Queue to keep track of remaining senators in order
#      remaining_senators = []
#      # Iterate over the senators in the given order
#      for senator in senate:
#          # If senator is from the Radiant party
#          if senator == 'R':
#              # If the senator is not already banned
#              if senator not in banned_senators:
#                  # Increment the count of R senators
#                  R += 1
#                  # Append the senator to the remaining senators queue
#                  remaining_senators.append(senator)
#              # If R and D senators are equal or Rsenators win
#              if R == D or R > D:
#                  # The Radiant party wins and break the loop
#                  break
#          # If senator is from the Dire party
#          elif senator == 'D':
#              # If the senator is not already banned
#              if senator not in banned_senators:
#                  # Increment the count of D senators
#                  D += 1
#                  # Append the senator to the remaining senators queue
#                  remaining_senators.append(senator)
#              # If R and D senators are equal or Dsenators win
#              if D == R or D > R:
#                  # The Dire party wins and break the loop
#                  break
#      # If all senators are banned and no party wins
#      if len(banned_senators) == len(senate) and R == D:
#          # The game remains a tie and break the loop
#          break
#      # Return the party that wins the game
#      return "Radiant" if R > D else "Dire"', x=[145, 384], edge_attr=[144, 384]),
#  Data(edge_index=[2, 153], y='codellama', num_nodes=154, node_texts=[154], edge_texts=[153], code='def get_maximum_subarray(arr):
#      if len(arr) == 1:
#          return arr[0], 0
#
#      mid = len(arr) // 2
#      left_max, left_sum = get_maximum_subarray(arr[:mid])
#      right_max, right_sum = get_maximum_subarray(arr[mid:])
#
#      max_left = 0
#      max_right = 0
#      for i in range(mid):
#          max_left = max(max_left, arr[i] + left_sum)
#
#      for j in range(mid, len(arr)):
#          max_right = max(max_right, arr[j] + right_sum)
#
#      return max(left_max, right_max, max_left + max_right), left_sum + right_sum', x=[154, 384], edge_attr=[153, 384]),
#  Data(edge_index=[2, 412], y='human', num_nodes=413, node_texts=[413], edge_texts=[412], code='
#
#
#
#  import sys
#  input=sys.stdin.readline #文字列入力はするな！！
#  from _collections import deque
#  from heapq import *
#  n=int(input())
#  a=[[]]
#  c=[0]*(n+1)
#  for i in range(1,n+1):
#      a.append(list(map(int,input().split())))
#      c[i]=a[i][0]
#      a[i][0]=-10**15
#  m=int(input())
#  ng=set()
#  for i in range(m):
#      x=[0]+list(map(int,input().split()))
#      ng.add(tuple(x))
#
#  hp=[]
#  res=0
#  for i in range(1,n+1):
#      res+=a[i][c[i]]
#  heappush(hp,(-res,(c[i] for i in range(n+1))))
#  seen=set()
#  while 1:
#      value,x=heappop(hp)
#      x=tuple(x)
#      value*=-1
#      if x not in ng:
#          x=list(x)
#          print(*x[1:])
#          exit()
#      x=list(x)
#      for i in range(1,n+1):
#          y=x[:]
#          value2=value-a[i][y[i]]
#          y[i]-=1
#          value2+=a[i][y[i]]
#          y=tuple(y)
#          if y not in seen:
#              seen.add(y)
#              heappush(hp,(-value2,y))
#
#
#
#
#  ', x=[413, 384], edge_attr=[412, 384]),
#  Data(edge_index=[2, 34], y='human', num_nodes=35, node_texts=[35], edge_texts=[34], code='def source(self, source):
#          """When the source gets updated, update the the options in the selector"""
#          BaseView.source.fset(self, source)
#          if self.select:
#              self.select.options = self.options', x=[35, 384], edge_attr=[34, 384]),
#  Data(edge_index=[2, 23], y='codellama', num_nodes=24, node_texts=[24], edge_texts=[23], code='def prefix_count(words, pref):
#      return len([word for word in words if word.startswith(pref)])', x=[24, 384], edge_attr=[23, 384]),
#  Data(edge_index=[2, 159], y='gpt', num_nodes=160, node_texts=[160], edge_texts=[159], code='import os
#  import subprocess
#  import yaml
#
#  def build_package(team, username, package, subpath, yaml_path):
#      """
#      Builds a package from a given Yaml file and installs it locally.
#
#      Returns the name of the package.
#      """
#      # Load the YAML file
#      with open(yaml_path, 'r') as file:
#          package_info = yaml.safe_load(file)
#
#      # Construct the package directory
#      package_dir = os.path.join(subpath, package)
#
#      # Check if the package directory exists
#      if not os.path.exists(package_dir):
#          os.makedirs(package_dir)
#
#      # Write the package information to a setup file
#      setup_file_content = f"""
#  from setuptools import setup, find_packages
#
#  setup(
#      name='{package}',
#      version='{package_info.get("version", "0.1.0")}',
#      packages=find_packages(),
#      install_requires={package_info.get("dependencies", [])},
#      author='{username}',
#      description='{package_info.get("description", "")}',
#  )
#  """
#
#      setup_file_path = os.path.join(package_dir, 'setup.py')
#      with open(setup_file_path, 'w') as setup_file:
#          setup_file.write(setup_file_content)
#
#      # Install the package locally
#      subprocess.run(['pip', 'install', '-e', package_dir], check=True)
#
#      return package', x=[160, 384], edge_attr=[159, 384]),
#  Data(edge_index=[2, 99], y='nxcode', num_nodes=100, node_texts=[100], edge_texts=[99], code='def _normalize_branch_node(self, node):
#      # if the left child of the node has only a single non-blank item
#      if len([ch for ch in node.left.children if ch.strip()!= '']) == 1:
#          # get the single non-blank item from the left child
#          child = node.left.children[0]
#          # replace the left child of the node with the single non-blank item
#          node.left = child
#      # if the right child of the node has only a single non-blank item
#      elif len([ch for ch in node.right.children if ch.strip()!= '']) == 1:
#          # get the single non-blank item from the right child
#          child = node.right.children[0]
#          # replace the right child of the node with the single non-blank item
#          node.right = child
#      return node', x=[100, 384], edge_attr=[99, 384]),
#  Data(edge_index=[2, 1950], y='human', num_nodes=1951, node_texts=[1951], edge_texts=[1950], code='# template taken from https://github.com/cheran-senthil/PyRival/blob/master/templates/template.py
#
#  import os
#  import sys
#  from io import BytesIO, IOBase
#  import math
#  from heapq import heappop, heappush, heapify, heapreplace
#  from collections import defaultdict, deque, OrderedDict
#  from bisect import bisect_left, bisect_right
#  #from functools import lru_cache
#  #import re
#  #from timeit import timeit
#  mod = 1000000007
#  mod1 = 998244353
#  #sys.setrecursionlimit(100090)
#  alpha = {'a': 0, 'b': 1, 'c': 2, 'd': 3, 'e': 4, 'f': 5, 'g': 6, 'h': 7, 'i': 8, 'j': 9, 'k': 10, 'l': 11, 'm': 12, 'n': 13, 'o': 14, 'p': 15, 'q': 16, 'r': 17, 's': 18, 't': 19, 'u': 20, 'v': 21, 'w': 22, 'x': 23, 'y': 24, 'z': 25}
#
#
#  def read():
#      sys.stdin  = open('input.txt', 'r')
#      sys.stdout = open('output.txt', 'w')
#
#  # ------------------------------------------- Algos --------------------------------------------------------
#  def primeFactors(n):
#      arr = []
#      l = 0
#      while n % 2 == 0:
#          arr.append(2)
#          l += 1
#          n = n // 2
#      for i in range(3,int(math.sqrt(n))+1,2):
#          while n % i== 0:
#              arr.append(i)
#              l += 1
#              n = n // i
#      if n > 2:
#          arr.append(n)
#          l += 1
#      return arr
#      #return l
#  def primeFactorsSet(n):
#      s = set()
#      while n % 2 == 0:
#          s.add(2)
#          n = n // 2
#      for i in range(3,int(math.sqrt(n))+1,2):
#          while n % i== 0:
#              s.add(i)
#              n = n // i
#      if n > 2:
#          s.add(n)
#      return s
#  def sieve(n):
#      res=[0 for i in range(n+1)]
#      #prime=set([])
#      prime=[]
#      for i in range(2,n+1):
#          if not res[i]:
#              #prime.add(i)
#              prime.append(i)
#              for j in range(1,n//i+1):
#                  res[i*j]=1
#      return prime
#  def isPrime(n) : # Check Prime Number or not
#      if (n <= 1) : return False
#      if (n <= 3) : return True
#      if (n % 2 == 0 or n % 3 == 0) : return False
#      i = 5
#      while(i * i <= n) :
#          if (n % i == 0 or n % (i + 2) == 0) :
#              return False
#          i = i + 6
#      return True
#  def countPrimesLessThanN(n):
#      seen, ans = [0] * n, 0
#      for num in range(2, n):
#          if seen[num]: continue
#          ans += 1
#          seen[num*num:n:num] = [1] * ((n - 1) // num - num + 1)
#      return ans
#  def gcd(x, y):
#      return math.gcd(x, y)
#  def lcm(a,b):
#      return (a // gcd(a,b))* b
#  def isBitSet(n,k):
#      # returns the count of numbers up to N having K-th bit set.
#      res = (n >> (k + 1)) << k
#      if ((n >> k) & 1):
#          res += n & ((1 << k) - 1)
#      return res
#  def popcount(x):
#      x = x - ((x >> 1) & 0x55555555)
#      x = (x & 0x33333333) + ((x >> 2) & 0x33333333)
#      x = (x + (x >> 4)) & 0x0f0f0f0f
#      x = x + (x >> 8)
#      x = x + (x >> 16)
#      return x & 0x0000007f
#  def modular_exponentiation(x, y, p):    #returns (x^y)%p
#      res = 1
#      x = x % p
#      if (x == 0) :
#          return 0
#      while (y > 0) :
#          if ((y & 1) == 1) :
#              res = (res * x) % p
#          y = y >> 1
#          x = (x * x) % p
#      return res
#  def nCr(n, r, p):    # returns nCr % p
#      num = den = 1
#      for i in range(r):
#          num = (num * (n - i)) % p
#          den = (den * (i + 1)) % p
#      return (num * pow(den,
#              p - 2, p)) % p
#  def smallestDivisor(n):
#      if (n % 2 == 0):
#          return 2
#      i = 3
#      while(i * i <= n):
#          if (n % i == 0):
#              return i
#          i += 2
#      return n
#  def numOfDivisors(n):
#      def pf(n):
#          dic = defaultdict(int)
#          while n % 2 == 0:
#              dic[2] += 1
#              n = n // 2
#          for i in range(3,int(math.sqrt(n))+1,2):
#              while n % i== 0:
#                  dic[i] += 1
#                  n = n // i
#          if n > 2:
#              dic[n] += 1
#          return dic
#      p = pf(n)
#      ans = 1
#      for item in p:
#          ans *= (p[item] + 1)
#      return ans
#  '''def SPF(spf, MAXN):
#      spf[1] = 1
#      for i in range(2, MAXN):
#          spf[i] = i
#      for i in range(4, MAXN, 2):
#          spf[i] = 2
#      for i in range(3, math.ceil(math.sqrt(MAXN))):
#          if (spf[i] == i):
#              for j in range(i * i, MAXN, i):
#                  if (spf[j] == j):
#                      spf[j] = i'''
#  # A O(log n) function returning prime
#  # factorization by dividing by smallest
#  # prime factor at every step
#  def factorizationInLogN(x, spf):
#      #ret = list()
#      dic = defaultdict(int)
#      while (x != 1):
#          #ret.append(spf[x])
#          dic[spf[x]] += 1
#          x = x // spf[x]
#      #return ret
#      return dic
#
#  '''MAXN = 10000001
#  spf = [0 for i in range(MAXN)]
#
#  SPF(spf, MAXN)'''
#
#  class DisjointSetUnion:
#      def __init__(self, n):
#          self.parent = list(range(n))
#          self.size = [1] * n
#          self.num_sets = n
#
#      def find(self, a):
#          acopy = a
#          while a != self.parent[a]:
#              a = self.parent[a]
#          while acopy != a:
#              self.parent[acopy], acopy = a, self.parent[acopy]
#          return a
#
#      def union(self, a, b):
#          a, b = self.find(a), self.find(b)
#          if a == b:
#              return False
#          if self.size[a] < self.size[b]:
#              a, b = b, a
#          self.num_sets -= 1
#          self.parent[b] = a
#          self.size[a] += self. size[b]
#          return True
#
#      def set_size(self, a):
#          return self.size[self.find(a)]
#
#      def __len__(self):
#          return self.num_sets
#  #a = sorted(range(n), key=arr.__getitem__)
#  # -------------------------------------------------- code -------------------------------------------------
#  def lis():
#      return [int(i) for i in input().split()]
#
#  def main():
#
#      t = int(input())
#      for _ in range(t):
#          a,b,c = map(int, input().split())
#          y = b
#          d = int(math.ceil((c-a)/b))
#
#          d += 1
#          x = d*b + a
#
#          print(x, y, c)
#
#
#  # ---------------------------------------------- region fastio ---------------------------------------------
#  BUFSIZE = 8192
#
#
#  class FastIO(IOBase):
#      newlines = 0
#
#      def __init__(self, file):
#          self._fd = file.fileno()
#          self.buffer = BytesIO()
#          self.writable = "x" in file.mode or "r" not in file.mode
#          self.write = self.buffer.write if self.writable else None
#
#      def read(self):
#          while True:
#              b = os.read(self._fd, max(os.fstat(self._fd).st_size, BUFSIZE))
#              if not b:
#                  break
#              ptr = self.buffer.tell()
#              self.buffer.seek(0, 2), self.buffer.write(b), self.buffer.seek(ptr)
#          self.newlines = 0
#          return self.buffer.read()
#
#      def readline(self):
#          while self.newlines == 0:
#              b = os.read(self._fd, max(os.fstat(self._fd).st_size, BUFSIZE))
#              self.newlines = b.count(b"\n") + (not b)
#              ptr = self.buffer.tell()
#              self.buffer.seek(0, 2), self.buffer.write(b), self.buffer.seek(ptr)
#          self.newlines -= 1
#          return self.buffer.readline()
#
#      def flush(self):
#          if self.writable:
#              os.write(self._fd, self.buffer.getvalue())
#              self.buffer.truncate(0), self.buffer.seek(0)
#
#
#  class IOWrapper(IOBase):
#      def __init__(self, file):
#          self.buffer = FastIO(file)
#          self.flush = self.buffer.flush
#          self.writable = self.buffer.writable
#          self.write = lambda s: self.buffer.write(s.encode("ascii"))
#          self.read = lambda: self.buffer.read().decode("ascii")
#          self.readline = lambda: self.buffer.readline().decode("ascii")
#
#
#  sys.stdin, sys.stdout = IOWrapper(sys.stdin), IOWrapper(sys.stdout)
#  input = lambda: sys.stdin.readline().rstrip("\r\n")
#
#  # -------------------------------------------------- end region ---------------------------------------------
#
#  if __name__ == "__main__":
#      #read()
#      main()', x=[1951, 384], edge_attr=[1950, 384])]

# %% [markdown]
# # pretrain

# %%
import os
import sys
import importlib
import torch
from torch_geometric.loader import DataLoader
from transformers import AutoTokenizer
import torch.optim as optim

# Ensure project root (one level up) is on the path so we can import CodeCLIP
root_dir = os.path.abspath("..")
if root_dir not in sys.path:
    sys.path.append(root_dir)

import CodeCLIP
importlib.reload(CodeCLIP)
from CodeCLIP import Pretrain

# Basic sanity checks on the dataset
if len(pyg_dataset) == 0:
    raise ValueError("pyg_dataset is empty. Please run the preprocessing cells first.")
if not hasattr(pyg_dataset[0], "x") or pyg_dataset[0].x is None:
    raise ValueError(
        "pyg_dataset graphs do not have node features 'x'. "
        "Make sure 'encode_text_graph' ran successfully before training."
    )

# Create checkpoint directory
checkpoint_dir = 'checkpoints/CodeClip'
os.makedirs(checkpoint_dir, exist_ok=True)
print(f"Checkpoints will be saved to: {checkpoint_dir}")

# Since our dataset is small (28 items), 128 is larger than the dataset.
batch_size = 128
# Create a DataLoader
loader = DataLoader(pyg_dataset, batch_size=batch_size, shuffle=True)

# Initialize Tokenizer
tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
vocab_size = tokenizer.vocab_size

# Initialize Model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

model = Pretrain(graph_in_dim=384, text_vocab_size=vocab_size, embed_dim=256).to(device)

optimizer = optim.Adam(model.parameters(), lr=1e-3)

# --- Resume from Checkpoint if exists ---
checkpoint_path = os.path.join(checkpoint_dir, 'checkpoint.pt')
if os.path.exists(checkpoint_path):
    print(f"Found checkpoint at {checkpoint_path}. Loading...")
    model.load_state_dict(torch.load(checkpoint_path))
    print("Checkpoint loaded successfully.")
else:
    print("No checkpoint found. Starting training from scratch.")
# ----------------------------------------

# Dummy training loop
num_epochs = 100

print("Starting training...")
model.train()

for epoch in range(num_epochs):
    total_loss = 0
    # loader yields batches of PyG Data objects
    for batch_idx, data in enumerate(loader):
        data = data.to(device)
        # Tokenize on the fly
        text_inputs = tokenizer(
            data.code, 
            padding=True, 
            truncation=True, 
            max_length=512, 
            return_tensors='pt'
        ).input_ids.to(device)
        
        optimizer.zero_grad()
        
        # Forward pass
        logits_graph, logits_text = model(data, text_inputs)
        
        # Loss
        loss = model.loss(logits_graph, logits_text)
        
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        
    avg_loss = total_loss / len(loader)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}")
    
    # Save checkpoint at the end of each epoch
    checkpoint_path = os.path.join(checkpoint_dir, 'checkpoint.pt')
    torch.save(model.state_dict(), checkpoint_path)

print(f"Training finished. Last model saved to {checkpoint_path}")
# Out:
# Checkpoints will be saved to: checkpoints/CodeClip
# Using device: cpu
# No checkpoint found. Starting training from scratch.
# Starting training...
# Epoch 1/100, Loss: 3.2580
# Epoch 2/100, Loss: 3.2593
# Epoch 3/100, Loss: 3.2586
# Epoch 4/100, Loss: 3.2550
# Epoch 5/100, Loss: 3.2529
# Epoch 6/100, Loss: 3.2468
# Epoch 7/100, Loss: 3.2257
# Epoch 8/100, Loss: 3.1652
# Epoch 9/100, Loss: 3.0929
# Epoch 10/100, Loss: 3.1473
# Epoch 11/100, Loss: 2.9465
# Epoch 12/100, Loss: 2.9051
# Epoch 13/100, Loss: 3.0593
# Epoch 14/100, Loss: 2.8248
# Epoch 15/100, Loss: 2.9570
# Epoch 16/100, Loss: 2.9181
# Epoch 17/100, Loss: 2.7680
# Epoch 18/100, Loss: 2.8233
# Epoch 19/100, Loss: 2.7524
# Epoch 20/100, Loss: 2.7931
# Epoch 21/100, Loss: 2.7124
# Epoch 22/100, Loss: 2.7650
# Epoch 23/100, Loss: 2.6988
# Epoch 24/100, Loss: 2.7263
# Epoch 25/100, Loss: 2.6727
# Epoch 26/100, Loss: 2.7175
# Epoch 27/100, Loss: 2.6500
# Epoch 28/100, Loss: 2.6607
# Epoch 29/100, Loss: 2.6303
# Epoch 30/100, Loss: 2.6190
# Epoch 31/100, Loss: 2.6251
# Epoch 32/100, Loss: 2.5991
# Epoch 33/100, Loss: 2.6147
# Epoch 34/100, Loss: 2.5784
# Epoch 35/100, Loss: 2.5861
# Epoch 36/100, Loss: 2.5741
# Epoch 37/100, Loss: 2.5606
# Epoch 38/100, Loss: 2.5582
# Epoch 39/100, Loss: 2.5487
# Epoch 40/100, Loss: 2.5449
# Epoch 41/100, Loss: 2.5374
# Epoch 42/100, Loss: 2.5235
# Epoch 43/100, Loss: 2.5354
# Epoch 44/100, Loss: 2.5361
# Epoch 45/100, Loss: 2.5294
# Epoch 46/100, Loss: 2.5138
# Epoch 47/100, Loss: 2.5138
# Epoch 48/100, Loss: 2.4974
# Epoch 49/100, Loss: 2.5042
# Epoch 50/100, Loss: 2.4816
# Epoch 51/100, Loss: 2.4927
# Epoch 52/100, Loss: 2.4739
# Epoch 53/100, Loss: 2.4802
# Epoch 54/100, Loss: 2.4634
# Epoch 55/100, Loss: 2.4708
# Epoch 56/100, Loss: 2.4523
# Epoch 57/100, Loss: 2.4582
# Epoch 58/100, Loss: 2.4474
# Epoch 59/100, Loss: 2.4467
# Epoch 60/100, Loss: 2.4376
# Epoch 61/100, Loss: 2.4392
# Epoch 62/100, Loss: 2.4380
# Epoch 63/100, Loss: 2.4276
# Epoch 64/100, Loss: 2.4216
# Epoch 65/100, Loss: 2.4212
# Epoch 66/100, Loss: 2.4327
# Epoch 67/100, Loss: 2.4201
# Epoch 68/100, Loss: 2.4130
# Epoch 69/100, Loss: 2.4158
# Epoch 70/100, Loss: 2.4189
# Epoch 71/100, Loss: 2.4066
# Epoch 72/100, Loss: 2.4004
# Epoch 73/100, Loss: 2.4024
# Epoch 74/100, Loss: 2.3956
# Epoch 75/100, Loss: 2.3932
# Epoch 76/100, Loss: 2.3915
# Epoch 77/100, Loss: 2.3854
# Epoch 78/100, Loss: 2.3818
# Epoch 79/100, Loss: 2.3787
# Epoch 80/100, Loss: 2.3716
# Epoch 81/100, Loss: 2.3678
# Epoch 82/100, Loss: 2.3617
# Epoch 83/100, Loss: 2.3557
# Epoch 84/100, Loss: 2.3504
# Epoch 85/100, Loss: 2.3447
# Epoch 86/100, Loss: 2.3370
# Epoch 87/100, Loss: 2.3313
# Epoch 88/100, Loss: 2.3247
# Epoch 89/100, Loss: 2.3182
# Epoch 90/100, Loss: 2.3118
# Epoch 91/100, Loss: 2.3075
# Epoch 92/100, Loss: 2.3129
# Epoch 93/100, Loss: 2.3078
# Epoch 94/100, Loss: 2.2963
# Epoch 95/100, Loss: 2.3083
# Epoch 96/100, Loss: 2.2984
# Epoch 97/100, Loss: 2.2788
# Epoch 98/100, Loss: 2.2844
# Epoch 99/100, Loss: 2.2745
# Epoch 100/100, Loss: 2.2641
# Training finished. Last model saved to checkpoints/CodeClip\checkpoint.pt

# %%
# Load the model from checkpoint and extract graph embeddings
model.eval()

# Load state dict
# checkpoint_path was defined in the previous cell ('checkpoints/CodeClip/checkpoint.pt')
if os.path.exists(checkpoint_path):
    print(f"Loading checkpoint from {checkpoint_path}")
    model.load_state_dict(torch.load(checkpoint_path))
else:
    print(f"Checkpoint {checkpoint_path} not found. Using current model state.")

graph_embeddings = []
model.to(device)

print("Extracting graph embeddings...")
with torch.no_grad():
    for batch_idx, data in enumerate(loader):
        data = data.to(device)
        features = model.graph_encoder(data.x, data.edge_index, data.edge_attr, data.batch)
        
        # Normalize if needed (CodeCLIP does it in forward, so we probably should too for consistency)
        features = features / features.norm(dim=1, keepdim=True)
        
        graph_embeddings.append(features.cpu())

# Concatenate all embeddings
if graph_embeddings:
    all_graph_embeddings = torch.cat(graph_embeddings, dim=0)
else:
    print("No embeddings extracted.")
# Out:
# Loading checkpoint from checkpoints/CodeClip\checkpoint.pt
# Extracting graph embeddings...

# %%
all_graph_embeddings
# Out:
# tensor([[-0.0638, -0.0230, -0.0162,  ..., -0.0089, -0.0978, -0.0595],
#         [-0.0528, -0.0327,  0.0692,  ...,  0.0388, -0.0550, -0.1068],
#         [-0.0578, -0.0226,  0.0551,  ...,  0.0423, -0.0759, -0.0872],
#         ...,
#         [ 0.0398,  0.0533,  0.0897,  ...,  0.0360,  0.0675, -0.0352],
#         [ 0.0279, -0.0061, -0.0966,  ..., -0.0464,  0.0104,  0.1138],
#         [-0.0118, -0.0729,  0.0037,  ...,  0.0582,  0.0405,  0.0537]])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Select the first embedding
embedding_vector = all_graph_embeddings[0, :].numpy()

# Create a bar plot
plt.figure(figsize=(12, 4))
plt.bar(range(len(embedding_vector)), embedding_vector, color='skyblue', width=1.0)
plt.title('Feature Vector Visualization (Item 0)')
plt.xlabel('Dimension Index')
plt.ylabel('Value')
plt.grid(True, alpha=0.3)

# Highlight max and min
max_idx = np.argmax(embedding_vector)
min_idx = np.argmin(embedding_vector)
plt.scatter([max_idx], [embedding_vector[max_idx]], color='red', label='Max', zorder=5)
plt.scatter([min_idx], [embedding_vector[min_idx]], color='green', label='Min', zorder=5)

plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np
import seaborn as sns

embeddings = all_graph_embeddings.detach().cpu().numpy()
labels = [data.y for data in pyg_dataset]

pca = PCA(n_components=2)
embeddings_2d = pca.fit_transform(embeddings)

plt.figure(figsize=(10, 8))
label_set = list(set(labels))

# Defines a more comprehensive color map
color_map = {
    'human': 'blue', 
    'gpt': 'red',
    'llama3.1': 'orange',
    'codellama': 'green',
    'qwen1.5': 'purple',
    'nxcode': 'cyan'
} 
# Fallback for unknown labels (using a palette)
fallback_colors = sns.color_palette("husl", len(label_set))

for i, label in enumerate(label_set):
    indices = [j for j, l in enumerate(labels) if l == label]
    if not indices: continue
    
    points = embeddings_2d[indices]
    
    # Use color_map if label exists, otherwise use fallback
    color = color_map.get(label, fallback_colors[i])
    
    plt.scatter(points[:, 0], points[:, 1], 
                c=[color], 
                label=label, alpha=0.7, s=100)

plt.title('PCA Visualization of Code Graph Embeddings by Model')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Get embeddings
embeddings = all_graph_embeddings.detach().cpu().numpy()

# 2. Apply Exponential Transformation
embeddings_exp = np.exp(embeddings) 

embeddings_exp = np.exp(embeddings) / np.sum(np.exp(embeddings), axis=1, keepdims=True)

plt.figure(figsize=(15, 6))

# 3. Plot
img = plt.imshow(embeddings_exp, cmap='coolwarm', aspect='auto', interpolation='nearest')

plt.colorbar(img, label='Exponential Activation (exp(x))')
plt.title('Heatmap of Graph Embeddings (Exponential Scaling)')
plt.xlabel('Feature Dimension')
plt.ylabel('Sample Index')

plt.yticks(range(len(embeddings)), labels=[f"Graph {i} ({l})" for i, l in enumerate(labels)])

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

embeddings_np = all_graph_embeddings.detach().cpu().numpy()
labels_list = [data.y for data in pyg_dataset]

sorted_indices = np.argsort(labels_list)
sorted_embeddings = embeddings_np[sorted_indices]
sorted_labels = np.array(labels_list)[sorted_indices]

exp_vals = np.exp(sorted_embeddings - np.max(sorted_embeddings, axis=1, keepdims=True))
embeddings_processed = exp_vals / np.sum(exp_vals, axis=1, keepdims=True)

plt.figure(figsize=(16, 8))

img = plt.imshow(embeddings_processed, cmap='coolwarm', aspect='auto', interpolation='nearest')

for i in range(1, len(sorted_labels)):
    if sorted_labels[i] != sorted_labels[i-1]:
        plt.axhline(y=i-0.5, color='black', linestyle='--', linewidth=1.5, alpha=0.8)

plt.colorbar(img, label='Activation Intensity (Softmax)')
plt.title('Sorted Heatmap of Graph Embeddings (Auto-Grouped)', fontsize=14)
plt.xlabel('Feature Dimension (0-256)', fontsize=12)
plt.ylabel('Samples (Grouped by Label)', fontsize=12)

plt.yticks(
    ticks=range(len(sorted_labels)), 
    labels=[f"{i}: {lbl}" for i, lbl in zip(sorted_indices, sorted_labels)],
    fontsize=8
)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Re-calculate sorted embeddings to ensure context (using variables from previous steps)
embeddings_np = all_graph_embeddings.detach().cpu().numpy()
labels_list = [data.y for data in pyg_dataset]

sorted_indices = np.argsort(labels_list)
sorted_embeddings = embeddings_np[sorted_indices]
sorted_labels = np.array(labels_list)[sorted_indices]

# Compute Cosine Similarity Matrix
# Normalize vectors to unit length
norms = np.linalg.norm(sorted_embeddings, axis=1, keepdims=True)
normalized_embeddings = sorted_embeddings / (norms + 1e-8)  # Avoid div by zero

# Compute dot product (NxN similarity matrix)
similarity_matrix = np.dot(normalized_embeddings, normalized_embeddings.T)

# Plot Heatmap
plt.figure(figsize=(10, 8))
# 'viridis' or 'coolwarm' are good choices. 'RdBu_r' is also good for -1 to 1 correlation.
# Since we deal with embeddings, values are likely > 0 if using ReLU, but cosine is -1 to 1.
# Let's use 'viridis' for general similarity or 'Blues'.
img = plt.imshow(similarity_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar(img, label='Cosine Similarity')

# Draw separation lines for groups
transitions = [i for i in range(1, len(sorted_labels)) if sorted_labels[i] != sorted_labels[i-1]]
for t in transitions:
    plt.axhline(y=t-0.5, color='blacK', linestyle='--', linewidth=1, alpha=0.7)
    plt.axvline(x=t-0.5, color='blacK', linestyle='--', linewidth=1, alpha=0.7)

plt.title('Pairwise Similarity Matrix (Sorted by Group)')
plt.xlabel('Samples (Sorted)')
plt.ylabel('Samples (Sorted)')

# Optional: Add group labels on axes
# Calculate center positions for labels
group_starts = [0] + transitions + [len(sorted_labels)]
tick_locs = []
group_names = []
for i in range(len(group_starts)-1):
    start = group_starts[i]
    end = group_starts[i+1]
    tick_locs.append((start + end) / 2)
    group_names.append(sorted_labels[start])

plt.xticks(tick_locs, group_names, rotation=45, ha='right')
plt.yticks(tick_locs, group_names)

plt.tight_layout()
plt.show()
